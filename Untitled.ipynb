# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}',
]
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
#plt.style.use('ggplot')

fp = [
    'test1/cmp.txt', 
    'test1/cmp_no_pre.txt',
    'test1/cmp_no_pre_no_dec.txt'
]
suptitles = [
    'The Mean of Test Accuracy',
    'The Deviations of Test Accuracy',
    'The Differences between FCN and HLN'
]
titles = [
    r'$N_{pre}=5000,\eta=1.0,\alpha=0.1$',
    r'$N_{pre}=0,\eta=1.0,\alpha=0.1$',
    r'$N_{pre}=0,\eta=1.0,\alpha=0.0$'
]
legends = [
    [
        r'$\mu_{FCN}$',
        r'$\mu_{HLN}$'
    ],
    [
        r'$\sigma_{FCN}$',
        r'$\sigma_{HLN}$'
    ],
    [
        r'$\Delta\mu=\mu_{HLN}-\mu_{FCN}$',
        r'$\Delta\sigma=\sigma_{HLN}-\sigma_{FCN}$'
    ]
]
xlabel = 'Epoch'
ylabels = [
    'Mean of Accuracy',
    'Deviation of Accuracy',
    'Difference'
]
styles = [
    ['k-', 'r-'],
    ['k--', 'r--'],
    ['y-', 'y--']
]
figs = [
    'mean_accuracy.png',
    'devi_accuracy.png',
    'delta_accuracy.png'
]

ntest = len(fp)
x = list(range(ntest))
mb = list(range(ntest))
mh = list(range(ntest))
md = list(range(ntest))
sb = list(range(ntest))
sh = list(range(ntest))
sd = list(range(ntest))

# loading the execution logs
for k in range(ntest):
    n = 0
    # counting the line number
    f = file(fp[k])
    s = f.readline()
    while(s!=''):
        n += 1
        s = f.readline()
    print('data contains ', n, 'tests.')
    # allocation
    x[k] = np.zeros(n)
    mb[k] = np.zeros(n)
    mh[k] = np.zeros(n)
    md[k] = np.zeros(n)
    sb[k] = np.zeros(n)
    sh[k] = np.zeros(n)
    sd[k] = np.zeros(n)
    # load data
    f = file(fp[k])
    for i in range(n):
        s = f.readline()
        arr = s.split(' ')
        x[k][i] = float(arr[0])/100
        mb[k][i] = float(arr[1])
        mh[k][i] = float(arr[2])
        md[k][i] = mh[k][i] - mb[k][i]
        sb[k][i] = np.sqrt(float(arr[3]))
        sh[k][i] = np.sqrt(float(arr[4]))
        sd[k][i] = sh[k][i] - sb[k][i]
        
# the mean accuracy comparison
plt.figure(dpi=100,figsize=[15,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], mb[i][:], styles[0][0])
    plt.plot(x[i][:], mh[i][:], styles[0][1])
    plt.legend(legends[0][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), 0, 1.0])
    if i==0:
        plt.ylabel(ylabels[0])
#plt.suptitle(suptitles[0])
plt.savefig(figs[0],dpi=100)

# the accuracy deviation comparison
plt.figure(dpi=100,figsize=[15,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], sb[i][:], styles[1][0])
    plt.plot(x[i][:], sh[i][:], styles[1][1])
    plt.legend(legends[1][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), 0, 1.0])
    if i==0:
        plt.ylabel(ylabels[1])
#plt.suptitle(suptitles[1])
plt.savefig(figs[1],dpi=100)

# the model differences
plt.figure(dpi=100,figsize=[15,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], md[i][:], styles[2][0])
    plt.plot(x[i][:], sd[i][:], styles[2][1])
    plt.legend(legends[2][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), -1.0, 1.0])
    if i==0:
        plt.ylabel(ylabels[2])
#plt.suptitle(suptitles[2])
plt.savefig(figs[2],dpi=100)
# Out:
# ('data contains ', 14, 'tests.')
# ('data contains ', 11, 'tests.')
# ('data contains ', 11, 'tests.')

# %%
#### draw the comparison between two Nets
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}',
]
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
#plt.style.use('ggplot')

fp_bp = [
    'test2/bp_196_30_10.txt',
    'test2/bp_196_30_20_10.txt',
    'test2/bp_487_30_10.txt',
    'test2/bp_487_40_20_10.txt'
]
fp_hl = [
    'test2/hl_196_30_10.txt',
    'test2/hl_196_30_20_10.txt',
    'test2/hl_487_30_10.txt',
    'test2/hl_487_40_20_10.txt'
]
# all logs are 81 lines to read
n1 = 81
# allocation
ntest = len(fp_bp)-1
t_bp = np.zeros([ntest,n1]) # bp epoch number
t_hl = np.zeros([ntest,n1]) # hl epoch number
l_bp = np.zeros([ntest,n1]) # bp training loss
l_hl = np.zeros([ntest,n1]) # hl training loss
a_bp = np.zeros([ntest,n1]) # bp accuracy
a_hl = np.zeros([ntest,n1]) # hl accuracy
# load data
for k in range(ntest):
    f = file(fp_bp[k])
    for i in range(n1):
        s = f.readline()
        s = s.replace('\n', '')
        s = s.replace('[', '')
        s = s.replace(']', '')
        s = s.replace(' ', '*')
        s = s.replace('\t\t', '*')
        s = s.replace('\t', '*')
        s = s.replace('****', '*')
        s = s.replace('***', '*')
        s = s.replace('**', '*')
        arr = s.split('*')
        t_bp[k,i] = float(arr[0])+1
        l_bp[k,i] = float(arr[1])
        a_bp[k,i] = float(arr[2])
    f = file(fp_hl[k])
    for i in range(n1):
        s = f.readline()
        s = s.replace('\n', '')
        s = s.replace('[', '')
        s = s.replace(']', '')
        s = s.replace(' ', '*')
        s = s.replace('\t\t', '*')
        s = s.replace('\t', '*')
        s = s.replace('****', '*')
        s = s.replace('***', '*')
        s = s.replace('**', '*')
        arr = s.split('*')
        t_hl[k,i] = float(arr[0])+1
        l_hl[k,i] = float(arr[1])
        a_hl[k,i] = float(arr[2])
# the last experiment is a bit special
n2 = 189
# allocation
ntest = 1
t_bp_4 = np.zeros([ntest,n2]) # bp epoch number
t_hl_4 = np.zeros([ntest,n2]) # hl epoch number
l_bp_4 = np.zeros([ntest,n2]) # bp training loss
l_hl_4 = np.zeros([ntest,n2]) # hl training loss
a_bp_4 = np.zeros([ntest,n2]) # bp accuracy
a_hl_4 = np.zeros([ntest,n2]) # hl accuracy
# load data
for k in range(ntest):
    f = file(fp_bp[k+3])
    for i in range(n2):
        s = f.readline()
        s = s.replace('\n', '')
        s = s.replace('[', '')
        s = s.replace(']', '')
        s = s.replace(' ', '*')
        s = s.replace('\t\t', '*')
        s = s.replace('\t', '*')
        s = s.replace('****', '*')
        s = s.replace('***', '*')
        s = s.replace('**', '*')
        arr = s.split('*')
        t_bp_4[k,i] = float(arr[0])+1
        l_bp_4[k,i] = float(arr[1])
        a_bp_4[k,i] = float(arr[2])
    f = file(fp_hl[k+3])
    for i in range(n2):
        s = f.readline()
        s = s.replace('\n', '')
        s = s.replace('[', '')
        s = s.replace(']', '')
        s = s.replace(' ', '*')
        s = s.replace('\t\t', '*')
        s = s.replace('\t', '*')
        s = s.replace('****', '*')
        s = s.replace('***', '*')
        s = s.replace('**', '*')
        arr = s.split('*')
        t_hl_4[k,i] = float(arr[0])+1
        l_hl_4[k,i] = float(arr[1])
        a_hl_4[k,i] = float(arr[2])
# draw first graph
plt.figure(dpi=100,figsize=[15,4])
plt.subplot(1,4,1)
plt.plot(t_bp[0,:], l_bp[0,:], 'k-')
plt.plot(t_hl[0,:], l_hl[0,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$196I-30H-10F$')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.axis([0, n1, 0, max(max(l_bp[0,:]),max(l_hl[0,:]))])

# draw another test
plt.subplot(1,4,2)
plt.plot(t_bp[1,:], l_bp[1,:], 'k-')
plt.plot(t_hl[1,:], l_hl[1,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$196I-30H-20H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n1, 0, max(max(l_bp[1,:]),max(l_hl[1,:]))])

# draw the third test
plt.subplot(1,4,3)
plt.plot(t_bp[2,:], l_bp[2,:], 'k-')
plt.plot(t_hl[2,:], l_hl[2,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$487I-30H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n1, 0, max(max(l_bp[2,:]),max(l_hl[2,:]))])

# draw the fourth test
plt.subplot(1,4,4)
plt.plot(t_bp_4[0,:], l_bp_4[0,:], 'k-')
plt.plot(t_hl_4[0,:], l_hl_4[0,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$487I-40H-20H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n2, 0, max(max(l_bp_4[0,:]),max(l_hl_4[0,:]))])

# save the first figure
plt.savefig('mnist_training_loss.png',dpi=100)

# draw first graph
plt.figure(dpi=100,figsize=[15,4])
plt.subplot(1,4,1)
plt.plot(t_bp[0,:], a_bp[0,:], 'k-')
plt.plot(t_hl[0,:], a_hl[0,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$196I-30H-10F$')
plt.xlabel('Epoch')
plt.ylabel('Testing Accuracy')
plt.axis([0, n1, 0, max(max(a_bp[0,:]),max(a_hl[0,:]))])

# draw second test
plt.subplot(1,4,2)
plt.plot(t_bp[1,:], a_bp[1,:], 'k-')
plt.plot(t_hl[1,:], a_hl[1,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$196I-30H-20H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n1, 0, max(max(a_bp[1,:]),max(a_hl[1,:]))])

# draw THIRD test
plt.subplot(1,4,3)
plt.plot(t_bp[2,:], a_bp[2,:], 'k-')
plt.plot(t_hl[2,:], a_hl[2,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$487I-30H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n1, 0, max(max(a_bp[2,:]),max(a_hl[2,:]))])

# draw FOURTH test
plt.subplot(1,4,4)
plt.plot(t_bp_4[0,:], a_bp_4[0,:], 'k-')
plt.plot(t_hl_4[0,:], a_hl_4[0,:], 'r-')
plt.legend(['FCN', 'HLN'])
plt.title(r'$487I-40H-20H-10F$')
plt.xlabel('Epoch')
plt.axis([0, n2, 0, max(max(a_bp_4[0,:]),max(a_hl_4[0,:]))])

plt.savefig('mnist_testing_accuracy.png',dpi=100)

# get sparsity data
n = 81
s_bp_1 = np.zeros(n) # fcn sparsity
s_hl_1 = np.zeros(n) # hln sparsity
f = file(fp_bp[2])
for i in range(n):
    s = f.readline()
    s = s.replace('\n', '')
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace(' ', '*')
    s = s.replace('\t\t', '*')
    s = s.replace('\t', '*')
    s = s.replace('****', '*')
    s = s.replace('***', '*')
    s = s.replace('**', '*')
    arr = s.split('*')
    s_bp_1[i] = float(arr[3])
f = file(fp_hl[2])
for i in range(n):
    s = f.readline()
    s = s.replace('\n', '')
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace(' ', '*')
    s = s.replace('\t\t', '*')
    s = s.replace('\t', '*')
    s = s.replace('****', '*')
    s = s.replace('***', '*')
    s = s.replace('**', '*')
    arr = s.split('*')
    s_hl_1[i] = float(arr[3])
# draw the sparsity graph
plt.figure(dpi=100, figsize=(8, 3))
plt.subplot(1,2,1)
plt.plot(range(n), s_bp_1, 'k-')
plt.plot(range(n), s_hl_1, 'r-')
plt.legend(['FCN', 'HLN'])
plt.xlabel('Epoch')
plt.ylabel('The ratio of activated neurons')
plt.axis([0, n, 0, 1.1])
plt.title(r'$487I-30H-10F$')

# next experiment
n = 189
s_bp_2 = np.zeros([2,n]) # fcn sparsity
s_hl_2 = np.zeros([2,n]) # hln sparsity
f = file(fp_bp[3])
for i in range(n):
    s = f.readline()
    s = s.replace('\n', '')
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace(' ', '*')
    s = s.replace('\t\t', '*')
    s = s.replace('\t', '*')
    s = s.replace('****', '*')
    s = s.replace('***', '*')
    s = s.replace('**', '*')
    arr = s.split('*')
    s_bp_2[0,i] = float(arr[3])
    s_bp_2[1,i] = float(arr[4])
f = file(fp_hl[3])
for i in range(n):
    s = f.readline()
    s = s.replace('\n', '')
    s = s.replace('[', '')
    s = s.replace(']', '')
    s = s.replace(' ', '*')
    s = s.replace('\t\t', '*')
    s = s.replace('\t', '*')
    s = s.replace('****', '*')
    s = s.replace('***', '*')
    s = s.replace('**', '*')
    arr = s.split('*')
    s_hl_2[0,i] = float(arr[3])
    s_hl_2[1,i] = float(arr[4])

# draw the sparsity graph
plt.subplot(1,2,2)
plt.plot(range(n), s_bp_2[0,:], 'k-')
plt.plot(range(n), s_hl_2[0,:], 'r-')
plt.plot(range(n), s_bp_2[1,:], 'c--')
plt.plot(range(n), s_hl_2[1,:], 'y--')
plt.legend(['FCN-H0', 'HLN-H0', 'FCN-H1', 'HLN-H1'])
plt.xlabel('Epoch')
plt.axis([0, n, 0, 1.1])
plt.title(r'$487I-40H-20H-10F$')

plt.savefig('mnist_training_sparsity.png', dpi=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a9eac499aff4> in <module>()
#      52         s = s.replace('**', '*')
#      53         arr = s.split('*')
# ---> 54         t_bp[k,i] = float(arr[0])+1
#      55         l_bp[k,i] = float(arr[1])
#      56         a_bp[k,i] = float(arr[2])
#
# ValueError: could not convert string to float:
