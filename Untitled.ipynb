# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}',
]
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

fp = [
    'test1/cmp.txt', 
    'test1/cmp_no_pre.txt',
    'test1/cmp_no_pre_no_dec.txt'
]
suptitles = [
    'The Mean of Test Accuracy',
    'The Deviations of Test Accuracy',
    'The Differences between FCN and HLN'
]
titles = [
    r'$N_{pre}=5000,\eta=1.0,\alpha=0.1$',
    r'$N_{pre}=0,\eta=1.0,\alpha=0.1$',
    r'$N_{pre}=0,\eta=1.0,\alpha=0.0$'
]
legends = [
    [
        r'$\mu_{FCN}$',
        r'$\mu_{HLN}$'
    ],
    [
        r'$\sigma_{FCN}$',
        r'$\sigma_{HLN}$'
    ],
    [
        r'$\Delta\mu=\mu_{HLN}-\mu_{FCN}$',
        r'$\Delta\sigma=\sigma_{HLN}-\sigma_{FCN}$'
    ]
]
xlabel = 'Epoch'
ylabels = [
    'Accuracy',
    'Deviation',
    'Difference'
]
styles = [
    ['b-', 'r-'],
    ['b--', 'r--'],
    ['y-', 'y--']
]
figs = [
    'mean_accuracy.png',
    'devi_accuracy.png',
    'delta_accuracy.png'
]

ntest = len(fp)
x = list(range(ntest))
mb = list(range(ntest))
mh = list(range(ntest))
md = list(range(ntest))
sb = list(range(ntest))
sh = list(range(ntest))
sd = list(range(ntest))

# loading the execution logs
for k in range(ntest):
    # counting the line number
    f = file(fp[k])
    n = 0
    s = f.readline()
    while(s!=''):
        n += 1
        s = f.readline()
    print('data contains ', n, 'tests.')
    # allocation
    x[k] = np.zeros(n)
    mb[k] = np.zeros(n)
    mh[k] = np.zeros(n)
    md[k] = np.zeros(n)
    sb[k] = np.zeros(n)
    sh[k] = np.zeros(n)
    sd[k] = np.zeros(n)
    # load data
    f = file(fp[k])
    for i in range(n):
        s = f.readline()
        arr = s.split(' ')
        x[k][i] = float(arr[0])/100
        mb[k][i] = float(arr[1])
        mh[k][i] = float(arr[2])
        md[k][i] = mh[k][i] - mb[k][i]
        sb[k][i] = np.sqrt(float(arr[3]))
        sh[k][i] = np.sqrt(float(arr[4]))
        sd[k][i] = sh[k][i] - sb[k][i]
        
# the mean accuracy comparison
plt.figure(dpi=100,figsize=[10,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], mb[i][:], styles[0][0])
    plt.plot(x[i][:], mh[i][:], styles[0][1])
    plt.legend(legends[0][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), 0, 1.0])
    if i==0:
        plt.ylabel(ylabels[0])
plt.suptitle(suptitles[0])
plt.savefig(figs[0],dpi=100)

# the accuracy deviation comparison
plt.figure(dpi=100,figsize=[10,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], sb[i][:], styles[1][0])
    plt.plot(x[i][:], sh[i][:], styles[1][1])
    plt.legend(legends[1][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), 0, 1.0])
    if i==0:
        plt.ylabel(ylabels[1])
plt.suptitle(suptitles[1])
plt.savefig(figs[1],dpi=100)

# the model differences
plt.figure(dpi=100,figsize=[10,4])
for i in range(ntest):
    plt.subplot(1,ntest,i+1)
    plt.plot(x[i][:], md[i][:], styles[2][0])
    plt.plot(x[i][:], sd[i][:], styles[2][1])
    plt.legend(legends[2][:])
    plt.title(titles[i])
    plt.xlabel(xlabel)
    plt.axis([0,max(x[0][:]), -1.0, 1.0])
    if i==0:
        plt.ylabel(ylabels[2])
plt.suptitle(suptitles[2])
plt.savefig(figs[2],dpi=100)
# Out:
# ('data contains ', 16, 'tests.')
# ('data contains ', 11, 'tests.')
# ('data contains ', 11, 'tests.')

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}',
]

import matplotlib.pyplot as plt
import numpy as np
import sys
import os

fp = 'test1/cmp_no_pre.txt'
num = 30
f = file(fp)
n = 0
s = f.readline()
while(s!=''):
    n += 1
    s = f.readline()
print('data contains ', n, 'tests.')
x = np.zeros(n)
mb = np.zeros(n)
mh = np.zeros(n)
md = np.zeros(n)
sb = np.zeros(n)
sh = np.zeros(n)
sd = np.zeros(n)
f = file(fp)
for i in range(n):
    s = f.readline()
    arr = s.split(' ')
    x[i] = float(arr[0])/100
    mb[i] = float(arr[1])
    mh[i] = float(arr[2])
    md[i] = mh[i] - mb[i]
    sb[i] = np.sqrt(float(arr[3]))
    sh[i] = np.sqrt(float(arr[4]))
    sd[i] = sh[i] - sb[i]
fig = plt.figure(dpi=100)
plt.plot(x, mb, 'b-')
plt.plot(x, mh, 'r-')
plt.plot(x, md, 'y-')
plt.plot(x, sb, 'b--')
plt.plot(x, sh, 'r--')
plt.plot(x, sd, 'y--')
plt.legend([r'$\mu-\textbf{FCN}$', \
            r'$\mu-\textbf{HLN}$', \
            r'$\Delta\mu$', \
            r'$\sigma-\textbf{FCN}$', \
            r'$\sigma-\textbf{HLN}$', \
            r'$\Delta\sigma$'\
            ])
plt.title(r'Single Hidden Layer Net($N_{pre}=0,\eta=1.0,\alpha=0.1$)')
plt.xlabel('Epoch(/times)')
fig.savefig('single_layer_no_pre.png', dpi=100)
# Out:
# ('data contains ', 11, 'tests.')

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}',
]

import matplotlib.pyplot as plt
import numpy as np
import sys
import os

fp = 'test1/cmp_no_pre_no_dec.txt'
num = 30
f = file(fp)
n = 0
s = f.readline()
while(s!=''):
    n += 1
    s = f.readline()
print('data contains ', n, 'tests.')
x = np.zeros(n)
mb = np.zeros(n)
mh = np.zeros(n)
md = np.zeros(n)
sb = np.zeros(n)
sh = np.zeros(n)
sd = np.zeros(n)
f = file(fp)
for i in range(n):
    s = f.readline()
    arr = s.split(' ')
    x[i] = float(arr[0])/100
    mb[i] = float(arr[1])
    mh[i] = float(arr[2])
    md[i] = mh[i] - mb[i]
    sb[i] = np.sqrt(float(arr[3]))
    sh[i] = np.sqrt(float(arr[4]))
    sd[i] = sh[i] - sb[i]
fig = plt.figure(dpi=100)
plt.plot(x, mb, 'b-')
plt.plot(x, mh, 'r-')
plt.plot(x, md, 'y-')
plt.plot(x, sb, 'b--')
plt.plot(x, sh, 'r--')
plt.plot(x, sd, 'y--')
plt.legend([r'$\mu-\textbf{FCN}$', \
            r'$\mu-\textbf{HLN}$', \
            r'$\Delta\mu$', \
            r'$\sigma-\textbf{FCN}$', \
            r'$\sigma-\textbf{HLN}$', \
            r'$\Delta\sigma$'\
            ])
plt.title(r'Single Hidden Layer Net($N_{pre}=0,\eta=1.0,\alpha=0$)')
plt.xlabel('Epoch(/times)')
fig.savefig('single_layer_no_pre_no_dec.png', dpi=100)
# Out:
# ('data contains ', 11, 'tests.')

# %%
# test HLN on MNIST database
# %matplotlib inline
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['text.latex.preamble'] = [
       '\\usepackage{CJK}',
       r'\AtBeginDocument{\begin{CJK}{UTF8}{gbsn}}',
       r'\AtEndDocument{\end{CJK}}']
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import struct
# using HLN to classify these digits
# MAX-OUT OPERATOR
def max_pool(ims, h, w, ph, pw):
    dim = ims.shape
    if dim[1] <> h*w:
        raise NameError('image dimension error')
    nh = (h-1)/ph + 1
    nw = (w-1)/pw + 1
    nims = np.zeros([dim[0], nh*nw])
    pool = np.zeros(ph*pw)
    for i in range(dim[0]):
        for j in range(nh):
            for k in range(nw):
                for s in range(ph):
                    for t in range(pw):
                        if j*ph+s>=h:
                            pool[s*pw+t] = 0
                        elif k*pw+t>=w:
                            pool[s*pw+t] = 0
                        else:
                            pool[s*pw+t] = ims[i,(j*ph+s)*w+k*pw+t]
                nims[i,j*nw+k] = np.max(pool)
    return [nims, nh, nw]
# reading MINST database
# load training images
filename = 'MNIST/train-images-idx3-ubyte'
binfile = open(filename , 'rb')
buf = binfile.read()
index = 0
magic,numImages,numRows,numColumns = \
    struct.unpack_from('>IIII' , buf , index)
index += struct.calcsize('>IIII')
if magic!=2051:
    raise NameError('MNIST TRAIN-IMAGE INCCORECT!')
ims = np.zeros([numImages, numRows*numColumns])
for i in range(numImages):
    ims[i,:] = struct.unpack_from('>784B', buf, index)
    index += struct.calcsize('>784B');
# loading training labels
filename = 'MNIST/train-labels-idx1-ubyte'
binfile = open(filename, 'rb')
buf = binfile.read()
index = 0
magic,numLabels = struct.unpack_from(
    '>II', 
    buf, 
    index
)
index += struct.calcsize('>II')
if magic!=2049:
    raise NameError('MNIST TRAIN-LABEL INCORRECT!')
lbs = np.zeros(numLabels)
lbs[:] = struct.unpack_from(
    '>'+ str(numLabels) +'B', 
    buf, 
    index
)
# apply max-pooling
ims1 = np.zeros([10,numRows*numColumns])
ims1[:,:]=ims[0:10,:]
h = numRows
w = numColumns
[ims1,h,w] = max_pool(ims1,h,w,2,2)

for i in range(10):
    im = np.array(ims1[i,:])
    im = im.reshape(h,w)
    fig = plt.subplot(1,10,i+1)
    fig.imshow(im , cmap='gray')
    fig.axis('off')
    plt.title(str(int(lbs[i])))
plt.show()

# deep HLN => DHLN
